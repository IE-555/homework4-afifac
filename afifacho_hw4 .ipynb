# %% [markdown]
# # Homework 4: Data Visualization
# - **Name**:  Afifa Choudhury
# - **UB Username**: afifacho
# - **UB Person Number**:  50363038
# - **UB Email ID**: afifacho@buffalo.edu

# %% [markdown]
# ---
# ## Part 1 - Generate Plots According to Specifications

# %% [markdown]
# ### Problem 1 - Scatter Plot with a Line

# %%
# %matplotlib notebook
# %matplotlib inline

import pandas as pd
import numpy as np
df = pd.read_csv('scatter_data.csv')

import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('scatter_data.csv')
df
# Out:
#           % x          y
# 0   95.954341  328.375777
# 1   60.162754  259.053445
# 2   52.754898  207.792989
# 3   88.034798  333.209632
# 4   80.271275  290.042475
# ..        ...         ...
# 95  60.430557  271.013639
# 96  56.943862  226.411831
# 97  93.616283  275.939404
# 98  91.772335  337.474381
# 99  99.863385  335.755833
#
# [100 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('scatter_data.csv')
plt.plot(df['% x'], df[' y '], 'g^', label="observations" )

# Create dashed line
min_x = 50
max_x = 100

min_y = 330
max_y = 335

# Plot the dashed red line
plt.plot([min_x, max_x],[min_y, max_y] , color='red', linestyle='--', label='extreme x points')

#Titles
plt.legend(loc="upper left")
plt.title('Widget Measurements')
plt.ylabel('y[inches]')
plt.xlabel('x[inches]')
plt.show()

# %% [markdown]
# ### Problem 2 - Histogram

# %%
dt = pd.read_csv('student_grades.csv')
dt
# Out:
#     % studentID   avgScore
# 0             0   81.563259
# 1             1   67.426527
# 2             2   86.415197
# 3             3   80.387361
# 4             4   76.669249
# ..          ...         ...
# 70           70   64.622963
# 71           71   86.951039
# 72           72   85.339374
# 73           73   69.082293
# 74           74  100.021837
#
# [75 rows x 2 columns]

# %%
dt = pd.read_csv('student_grades.csv')

A = dt[(dt[' avgScore '] >= 90) & (dt[' avgScore '] < 100)]
B = dt[(dt[' avgScore '] >= 80) & (dt[' avgScore '] < 90)]
C = dt[(dt[' avgScore '] >= 70) & (dt[' avgScore '] < 80)]
D = dt[(dt[' avgScore '] >= 60) & (dt[' avgScore '] < 70)]
F = dt[(dt[' avgScore '] < 60)]

A['studentID'] = 'A'
B['studentID'] = 'B'
C['studentID'] = 'C'
D['studentID'] = 'D'
F['studentID'] = 'F'

grades = pd.concat([A,B,C,D,F])
histdata = grades['studentID'].value_counts()
histdata_real = histdata.sort_index(ascending=False)
print(histdata_real)

plot = plt.bar(histdata_real.index, histdata_real, edgecolor = 'black', color = 'orange')
plt.xlabel('Grade')
plt.ylabel('Count')
plt.title('Grade Distribution')

for bar in plot:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, str(int(height)), ha='center', va='bottom')

plt.show()
# Out:
# F     3
# D    14
# C    21
# B    28
# A     5
# Name: studentID, dtype: int64
# /var/folders/8k/hp3mmqbn2h94jzr8yf1vr4w80000gn/T/ipykernel_1359/2262037611.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   A['studentID'] = 'A'
# /var/folders/8k/hp3mmqbn2h94jzr8yf1vr4w80000gn/T/ipykernel_1359/2262037611.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   B['studentID'] = 'B'
# /var/folders/8k/hp3mmqbn2h94jzr8yf1vr4w80000gn/T/ipykernel_1359/2262037611.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   C['studentID'] = 'C'
# /var/folders/8k/hp3mmqbn2h94jzr8yf1vr4w80000gn/T/ipykernel_1359/2262037611.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   D['studentID'] = 'D'
# /var/folders/8k/hp3mmqbn2h94jzr8yf1vr4w80000gn/T/ipykernel_1359/2262037611.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   F['studentID'] = 'F'

# %% [markdown]
# ### Problem 3 - Barplot and Boxplot in the Same Figure

# %%
import matplotlib.pyplot as plt

# Data for the bar plot
# Used excel to clean out the data 

data = pandas.read_csv('solution_data.csv')
x_bar = ['genetic algorithm', 'simulated annealing', 'tabu search']
y_bar = [32, 45, 31]

# Data for the box plot
genetic_algorithm = [32.14795493, 34.57364293, 34.02741285, 32.18697038, 32.81983329, 34.1986399, 29.46020717, 29.1969368, 34.65313335, 31.71667264]
simulated = [54.73259966, 30.06071003, 56.900812, 48.34413831, 56.08845406, 23.98538739, 41.91505173, 63.74293061, 56.71359499, 20.37715844]
tabu = [32.85544351, 15.65115853, 44.99103325, 24.37973539, 23.03309612, 25.72271226, 44.72428896, 30.18763166, 39.98254452, 31.38283123]

# Single figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# bar plot on the left subplot
ax1.bar(x_bar, y_bar, color='orange', edgecolor='black')
ax1.set_xlabel('Heuristic Method')
ax1.set_ylabel('Optimality Gap (%)')
ax1.set_title('Mean Gaps')
ax1.set_ylim(0,65)

# box plot on the right subplot
ax2.boxplot([genetic_algorithm, simulated, tabu], labels=['genetic algorithm', 'simulated annealing', 'tabu search'])
ax2.set_xlabel('Heauristic Method')
ax2.set_title('Distribution of Gaps')
plt.ylim(0, 65)

# title for the entire figure
fig.suptitle('Comparison of Optimality Gaps for Heuristics', fontsize=16)

# spacing between subplots
plt.subplots_adjust(wspace=0.05)

plt.show()

# %% [markdown]
# ---
# ## Part 2 - Explore New Plot Types

# %% [markdown]
# ### Data based on How Much Sleep Do Americans Really Get?
# - Used Violin plot to show the distribution of sleep americans get per day.
# - Data on the average amount of time Americans spend sleeping, broken down by age group, sex, and activity.
# - includes both weekdays and weekends, so you can see how our sleep habits change depending on the day of the week.

# %% [markdown]
# - **URL of Example Code**: https://seaborn.pydata.org/examples/wide_form_violinplot.html
# - **URL of Sample Data**:  https://www.kaggle.com/datasets/thedevastator/how-much-sleep-do-americans-really-get/data
# - **Dataset**: Time Americans Spend Sleeping.csv

# %%
df = pandas.read_csv('Time Americans Spend Sleeping.csv')
df
# Out:
#      index  Year  Period  Avg hrs per day sleeping  Standard Error  \
# 0        0  2003  Annual                      8.57           0.018
# 1        1  2004  Annual                      8.55           0.026
# 2        2  2005  Annual                      8.62           0.023
# 3        3  2006  Annual                      8.63           0.024
# 4        4  2007  Annual                      8.57           0.024
# ..     ...   ...     ...                       ...             ...
# 940    940  2013  Annual                      8.83           0.085
# 941    941  2014  Annual                      8.98           0.086
# 942    942  2015  Annual                      8.83           0.074
# 943    943  2016  Annual                      8.92           0.071
# 944    944  2017  Annual                      8.81           0.091
#
#             Type of Days          Age Group  Activity    Sex
# 0               All days  15 years and over  Sleeping   Both
# 1               All days  15 years and over  Sleeping   Both
# 2               All days  15 years and over  Sleeping   Both
# 3               All days  15 years and over  Sleeping   Both
# 4               All days  15 years and over  Sleeping   Both
# ..                   ...                ...       ...    ...
# 940  Nonholiday weekdays  65 years and over  Sleeping  Women
# 941  Nonholiday weekdays  65 years and over  Sleeping  Women
# 942  Nonholiday weekdays  65 years and over  Sleeping  Women
# 943  Nonholiday weekdays  65 years and over  Sleeping  Women
# 944  Nonholiday weekdays  65 years and over  Sleeping  Women
#
# [945 rows x 9 columns]

# %%
# Create a violin plot
plt.figure(figsize=(12, 6))
sns.violinplot(x="Year", y="Avg hrs per day sleeping", data=df)
plt.xticks(rotation=90)
plt.title('Violin Plot of Average Hours of Sleep per Day Over the Years')
plt.show()

# %% [markdown]
# # The violin plot shows where most of the data is centered.
# - Most of the data is centered at the middle of the plot for the average hours of sleep a day americans recieve between the years 2003 to 2017 which is around 8.7 hours of sleep per day.
# - The average of sleep lowers at 2004, 2007, 2012 and 2017
# - Most variation occurs in 2016
